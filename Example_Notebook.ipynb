# %% [markdown]
# <a href="https://colab.research.google.com/github/LightnerAndrew/PythonTutorial/blob/master/Example_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Example Notebook in Google Docs
#
# This notebook explores how we may use co-working notebooks in python to expand how we work in the ESDB and beyond.

# %% [markdown]
# # New Section

# %%
import pandas as pd
import numpy as np

! pip install xlrd
! pip install bokeh
# Out:
# ...
#     100% |████████████████████████████████| 16.1MB 2.2MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/04/dc/69/0fe79e7fa6a44f344d5be532011ff43a362ed60060d82589be
# Successfully built bokeh
# ...

# %%
data = pd.read_excel('NorthernKenya_ZOI_Interim_Codebook.xlsx', )

# %%
data.head()
# Out:
#   The “Variable_List” worksheet of the Northern Kenya 2015 ZOI Interim Survey codebook lists the dataset name, variable name, variable label, variable description, variable data type, and (where applicable) value label names.  The “Notes” column in this worksheet provides helpful information regarding specific variables.  Both original and derived (analysis) variables are included in this Codebook.  \
# 0  Northern Kenya ZOI Interim Survey\nCodebook - ...
# 1                This cell intentionally left blank.
# 2                                        DataSetName
# 3                               KEN_CHILDREN_FILE_PR
# 4                               KEN_CHILDREN_FILE_PR
#
#      Unnamed: 1                             Unnamed: 2  \
# 0           NaN                                    NaN
# 1           NaN                                    NaN
# 2  VariableName                          VariableLabel
# 3    age_cmpmth          Child age in completed months
# ...

# %%
import numpy as np

from bokeh.io import output_notebook, show
from bokeh.models import HoverTool
from bokeh.plotting import figure

n = 500
x = 2 + 2*np.random.standard_normal(n)
y = 2 + 2*np.random.standard_normal(n)

p = figure(title="Hexbin for 500 points", match_aspect=True,
           tools="wheel_zoom,reset", background_fill_color='#440154')
p.grid.visible = False

r, bins = p.hexbin(x, y, size=0.5, hover_color="pink", hover_alpha=0.8)

p.circle(x, y, color="white", size=1)

p.add_tools(HoverTool(
    tooltips=[("count", "@c"), ("(q,r)", "(@q, @r)")],
    mode="mouse", point_policy="follow_mouse", renderers=[r]
))

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1156">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="88248455-f58f-44d0-8c4e-626b3b885c78"></div>

# %%
from dask_kubernetes import KubeCluster
cluster = KubeCluster(n_workers=20)
cluster
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-2f0e37a4f4c6> in <module>()
#       1 from dask_kubernetes import KubeCluster
# ----> 2 cluster = KubeCluster(n_workers=20)
#       3 cluster
#
# /usr/local/lib/python3.6/dist-packages/dask_kubernetes/core.py in __init__(self, pod_template, name, namespace, n_workers, host, port, env, **kwargs)
#     173             msg = ("Worker pod specification not provided. See KubeCluster "
#     174                    "docstring for ways to specify workers")
# --> 175             raise ValueError(msg)
#     176
#     177         self.cluster = LocalCluster(ip=host or socket.gethostname(),
#
# ValueError: Worker pod specification not provided. See KubeCluster docstring for ways to specify workers

# %%
! pip install dask
# Out:
# ...
#     100% |████████████████████████████████| 696kB 9.4MB/s
# ...

# %%
! pip install dask_kubernetes
# Out:
# ...
#     100% |████████████████████████████████| 501kB 10.0MB/s
# ...
#     100% |████████████████████████████████| 1.4MB 10.8MB/s
# ...
#     100% |████████████████████████████████| 81kB 22.5MB/s
# ...
#     100% |████████████████████████████████| 61kB 21.5MB/s
# ...
#     100% |████████████████████████████████| 204kB 8.9MB/s
# ...
#     100% |████████████████████████████████| 2.1MB 13.2MB/s
# ...
#     100% |████████████████████████████████| 430kB 18.2MB/s
# ...
#     100% |████████████████████████████████| 102kB 27.2MB/s
# ...
#     100% |████████████████████████████████| 163kB 20.8MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/40/b9/42/344857b482c954f48bcff6db72d388e30bf2bee4ed14706faa
# done
#   Stored in directory: /root/.cache/pip/wheels/f2/9a/90/de94f8556265ddc9d9c8b271b0f63e57b26fb1d67a45564511
# Successfully built heapdict pycparser
# ...

# %%
! pip install intake
# Out:
# ...
#     100% |████████████████████████████████| 2.0MB 10.4MB/s
# ...
#     100% |████████████████████████████████| 143kB 12.8MB/s
# ...
#     100% |████████████████████████████████| 225kB 13.7MB/s
# ...
#     100% |████████████████████████████████| 665kB 14.0MB/s
# ...
#     100% |████████████████████████████████| 3.6MB 8.7MB/s
# ...
#     100% |████████████████████████████████| 112kB 28.4MB/s
# ...
#     100% |████████████████████████████████| 71kB 24.9MB/s
# ...
#     100% |████████████████████████████████| 2.2MB 12.5MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/e8/7a/6c/1d6450378acec487aa8c38db109a2cdf8fe81feed6bb113ec5
# done
#   Stored in directory: /root/.cache/pip/wheels/d5/de/86/7fa56fda12511be47ea0808f3502bc879df4e63ab168ec0406
# error
# ...
